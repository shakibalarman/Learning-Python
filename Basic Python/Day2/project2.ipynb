# %%
#name = input("Enter the name of a student")
math = int(input("Math = "))
if (math>100 ):
    print("Invalid input ")
    print("Please give correct input ")
    print(" Please enter your mark between 0 to 100")
elif (math<0):
    print("Invalid input ")
    print("Please give correct input ")
    print(" Please enter your mark between 0 to 100")
print("Your mark is ", math)
# Out:
# Invalid input
# Please give correct input
#  Please enter your mark between 0 to 100
# Your mark is  106

# %%
print("Grade")
math = int(input("Please enter your mark "))
if (math >100 and math<0):
    print("Invalid input")
     print("Please enter the mark between (0-100)")
    math = int(input("Please enter your mark "))
else:
    print("Please enter the mark between (0-100)")

#math1 = int(input("Please enter your mark "))
# Out:
# Grade
# Please enter the mark between (0-100)

# %%
math = int(input("Math = "))
if (math>100 or math < 0):
    print("invalid ")
    
    if(math < 40)
else:
# Out:
#   Cell In[19], line 5
#     if(math < 40)
#                  ^
# SyntaxError: expected ':'
